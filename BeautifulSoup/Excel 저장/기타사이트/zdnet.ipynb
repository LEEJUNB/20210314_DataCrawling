# %%
import os,re
import urllib.request as ur # 웹 데이터 다루는 패키지 > 웹 데이터 읽는 모듈
from bs4 import BeautifulSoup as bs # 자료 추출
news = "https://zdnet.co.kr/column/"
news_ur = ur.urlopen(news).read() # 해당 링크 데이터를 읽음

# [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-3-e219787bd929> in <module>
#       3 from bs4 import BeautifulSoup as bs # 자료 추출
#       4 news = "https://zdnet.co.kr/column/"
# ----> 5 news_ur = ur.urlopen(news).read() # 해당 링크 데이터를 읽음
#       6
#       7 # [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ...
