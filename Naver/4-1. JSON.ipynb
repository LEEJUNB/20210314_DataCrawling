# %%
import json

# 네이버에서 andoird키워드 검색시 나온 리스트 결과 (json포맷)
data = '''
{
    "lastBuildDate": "Mon, 09 Mar 2020 15:41:38 +0900",
    "total": 21285,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "교육부, &lt;코로나19 대응을 위한 교육 분야 학사운영 및 지원방안&gt; 발표",
            "originallink": "http://www.naeil.com/news_view/?id_art=343037",
            "link": "http://www.naeil.com/news_view/?id_art=343037",
            "description": "net) -모바일 앱: 앱스토어(IOS), 플레이스토어(<b>Android</b>) 이용 뷰어 설치 ②웹 버전: 디지털교과서 웹 접속 후 이용 (https://webdt.edunet.net) ※ 크롬, 사파리, 웨일, 엣지, 폭스 등 권장(익스플로러 미지원) 초3~중3 (사, 과, 영)... ",
            "pubDate": "Mon, 09 Mar 2020 14:40:00 +0900"
        },
        {
            "title": "[민간기업 일자리 정보+] 현대자동차,주식회사 카카오, 대림산업, NHN,롯데그...",
            "originallink": "http://www.fintechpost.co.kr/news/articleView.html?idxno=103951",
            "link": "http://www.fintechpost.co.kr/news/articleView.html?idxno=103951",
            "description": "▲ 채용회사명 : 네이버(주), 채용공고명 : &quot;[Search &amp; Clova] 파파고 앱 <b>Android</b> 개발 경력사원 모집&quot;, 담당업무... ▲ 채용회사명 : 주식회사 카카오, 채용공고명 : &quot;카카오맵 안드로이드(<b>Android</b>) 개발자 모집&quot;, 담당업무... ",
            "pubDate": "Sat, 07 Mar 2020 16:22:00 +0900"
        },
        {
            "title": "‘Star Trek: Picard’ Season 1, Episode 7 Recap: Will Riker Makes Pizza",
            "originallink": "https://www.nytimes.com/2020/03/06/arts/television/star-trek-picard-nepenthe-recap.html?partner=naver",
            "link": "https://www.nytimes.com/2020/03/06/arts/television/star-trek-picard-nepenthe-recap.html?partner=naver",
            "description": "his <b>android</b> friend. The series creators have said that the show should be viewed more as a... Soji slowly but surely comes to terms with her discovery that she is an <b>android</b>. Kestra helps her get... ",
            "pubDate": "Fri, 06 Mar 2020 22:37:00 +0900"
        },
        {
            "title": "이젠아카데미컴퓨터학원, 최신 트렌드 반영한 자바 안드로이드 웹앱 개발, 파...",
            "originallink": "http://www.fntoday.co.kr/news/articleView.html?idxno=212115",
            "link": "http://www.fntoday.co.kr/news/articleView.html?idxno=212115",
            "description": "국비지원 무료교육과정으로는 ▶자바(Java) 안드로이드 앱(<b>Android</b> APP) 개발 ▶파이썬(Python) ▶빅데이터 개발 분석(R), 자바 안드로이드 웹&amp;앱 UI·UX 개발, 프론트엔드(Front-end)·백엔드(Back-end) 개발, 노드(Node JS), 리엑트... ",
            "pubDate": "Fri, 06 Mar 2020 17:02:00 +0900"
        },
        {
            "title": "2020 Genesis G90 and Mint Concept named 'GOOD DESIGN® awards' winner",
            "originallink": "http://www.wikileaks-kr.org/news/articleView.html?idxno=79604",
            "link": "http://www.wikileaks-kr.org/news/articleView.html?idxno=79604",
            "description": "The 2020 G90 introduces multiple technology firsts for the Genesis brand, including a 12.3-inch display navigation system with touchscreen controls, standard Apple CarPlay and <b>Android</b> Auto, and an... ",
            "pubDate": "Fri, 06 Mar 2020 13:42:00 +0900"
        },
        {
            "title": "머스탱이 순수전기차로 나오면 이런 모습 '마하-E' 공개",
            "originallink": "http://www.gpkorea.com/news/articleView.html?idxno=62307",
            "link": "http://www.gpkorea.com/news/articleView.html?idxno=62307",
            "description": "또한 클라우드 기반 기술로 애플 카플레이(Apple CarPlay)와 안드로이드 오토(<b>Android</b> Auto) 등 인포테인먼트 시스템과도 무선으로 연동이 가능하다. 포드는 전기차 충전 인프라 확대에도 힘쓰고 있다. 포드는 향후 유럽... ",
            "pubDate": "Fri, 06 Mar 2020 13:20:00 +0900"
        },
        {
            "title": "포드, 유럽에서 순수전기차 '머스탱 마하-E' 최초 공개",
            "originallink": "http://www.wikileaks-kr.org/news/articleView.html?idxno=79557",
            "link": "http://www.wikileaks-kr.org/news/articleView.html?idxno=79557",
            "description": "또한 클라우드 기반 기술로 애플 카플레이(Apple CarPlay)와 안드로이드 오토(<b>Android</b> Auto) 등 인포테인먼트 시스템과도 무선으로 연동이 가능하다. 포드는 이 외에도 전기차 사용을 확대하기 위해 다방면으로 노력하고... ",
            "pubDate": "Fri, 06 Mar 2020 10:10:00 +0900"
        },
        {
            "title": "中 리얼미, 중급 스마트폰 '리얼미6' 시리즈 발표.. 64MP 쿼드 카메라·90Hz ...",
            "originallink": "http://kbench.com/?q=node/208255",
            "link": "http://kbench.com/?q=node/208255",
            "description": "배터리 및 <b>Android</b> 10 기반 리얼미 UI, 3.5mm 헤드폰 잭은 두 제품 모두 동일하다. '리얼미6' 시리즈 가격은 일반 모델 4GB/64GB 버전이 1만 2999루피(약 21만원), 프로 모델 6GB/64GB 버전이 1만 6999루피(약 27만원)... ",
            "pubDate": "Fri, 06 Mar 2020 10:06:00 +0900"
        },
        {
            "title": "젤리빔 초미니 스마트 프로젝터, 오프라인 스토어에서도 만난다",
            "originallink": "http://www.dailygrid.net/news/articleView.html?idxno=348236",
            "link": "http://www.dailygrid.net/news/articleView.html?idxno=348236",
            "description": "특히 <b>Android</b> OS를 탑재해 스마트폰, 태블릿 등의 주변기기 없이 인터넷과 동영상을 이용할 수 있는 점이 큰 장점이다. WI-Fi 연결과 앱을 통해 동영상 스트리밍을 자유롭게 즐길 수 있고, 스마트폰 등의 다양한 스마트... ",
            "pubDate": "Fri, 06 Mar 2020 08:56:00 +0900"
        },
        {
            "title": "Stop Your Phone From Using So Much Data",
            "originallink": "https://www.nytimes.com/2020/03/05/smarter-living/phone-data-usage.html?partner=naver",
            "link": "https://www.nytimes.com/2020/03/05/smarter-living/phone-data-usage.html?partner=naver",
            "description": "Google’s <b>Android</b> software, open the Settings app and head to Network &amp; Internet &gt; Mobile... On <b>Android</b>, open the Google Play Store, tap the three lines in the upper left corner, and head to... ",
            "pubDate": "Fri, 06 Mar 2020 06:30:00 +0900"
        }
    ]
}
'''
json_data = json.loads(data)
print(json_data['items'][1]['title'])
print(json_data['items'][1]['link'])
# Out:
# [민간기업 일자리 정보+] 현대자동차,주식회사 카카오, 대림산업, NHN,롯데그...
# http://www.fintechpost.co.kr/news/articleView.html?idxno=103951
