# %%
import requests
from bs4 import BeautifulSoup
# from urllib.request import urlopen # 이게 없어도 나타난다.
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
seeko = 'https://seeko.earlyadopter.co.kr/bbs/board.php?bo_table=freeboard3_1'
clien = 'https://www.clien.net/service/recommend'
res = requests.get(clien,headers=headers)
soup = BeautifulSoup(res.content,'html.parser')

# %% [markdown]
# - Q) 분명 해당 텍스트가 있는 것을 copy select를 해도 NoneType으로 나오는 경우는 이유가 뭐지? 사이트에서 막은건가?
# - Q) 하단 코드 출력문처럼 split을 통해 리스트화 시켰을 때 ''이 많은데 ''을 아예없앨 수는 없나?
# - A) 아마 .replace(), .get_text()처럼 바꾸는것이 있을 것이다

# %%
mydata = soup.select('#div_content > div.recommend_underList > div > div')

# %%
for item in mydata :
    new1 = item.get_text().replace('\t', '').split('\n')
    print(new1)
# Out:
# ['', '131', '', '', '모공', "외신) 확진자 7천명 돌파, 엉망이 된 이탈리아의 '봉쇄령 조치'", '', '', '', '54', '', '', '', '', '', '', '', '', '', '', '31.6 k', '', '', '', '02:53', '2020-03-09 02:53:53', '', '', '']
# ['', '308', '', '', '모공', "마스크 국내 생산 1위 웰킵스 사장 '마스크 대란 작심 비판'", '', '', '49', '', '', '', '', '', '', '페스페스', '', '', '', '31.0 k', '', '', '', '01:35', '2020-03-09 01:35:26', '', '', '']
# ['', '43', '', '', '모공', '대구에 삽니다.', '', '', '', '99', '', '', '', '', '', '', '아메먹는하마', '', '', '', '17.0 k', '', '', '', '00:57', '2020-03-09 00:57:34', '', '', '']
# ['', '85', '', '', '모공', '대구 사람이 보는 대구 영감들의 정확한 민심 (스압주의)', '', '', '55', '', '', '', '', '', '', '', '', '', '', '16.8 k', '', '', '', '02:22', '2020-03-09 02:22:37', '', '', '']
# ['', '16', '', '', '모공', '양희은씨가 구원파 신자였네요', '', '', '41', '', '', '', '', '', '', '모두가_행복했으면', '', '', '', '32.5 k', '', '', '', '03:52', '2020-03-09 03:52:46', '', '', '']
# ...
